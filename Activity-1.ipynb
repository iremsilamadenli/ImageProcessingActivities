# %% [markdown]
# # Add/Display an image in Jupyter Notebook

# %% [raw]
# -> Using IPython display (png , jpeg, can show gif as animation)
#
#         from IPython import display
#         display.Image("dog.png")
# -> using PIL image(but this one doesnt ahow gif as animation)
#
#        from IPython import display
#        display.Image("dog.png")

# %%
from IPython import display
display.Image("dog.png")
